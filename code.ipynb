# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
print("hello")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# hello

# %%
x = pd.read_csv("data.csv")
x
# Out:
#           Log_ID   User_ID    Log_Date Activity_Type  Duration_Minutes  \
# 0     LOG-502564  USR-2160  2024-01-01   Gym Workout               118
# 1     LOG-502968  USR-2237  2024-01-01       Cycling                32
# 2     LOG-503489  USR-2157  2024-01-01       Cycling                23
# 3     LOG-503464  USR-2040  2024-01-01          Yoga               107
# 4     LOG-503429  USR-2084  2024-01-01          HIIT                87
# ...          ...       ...         ...           ...               ...
# 3495  LOG-501088  USR-2179  2024-12-31   Gym Workout                43
# 3496  LOG-500706  USR-2200  2024-12-31   Gym Workout                94
# 3497  LOG-503184  USR-2102  2024-12-31      Swimming                28
# 3498  LOG-502469  USR-2231  2024-12-31          Yoga                41
# 3499  LOG-502716  USR-2143  2024-12-31      Swimming                42
#
#       Calories_Burned  Steps_Count  Avg_Heart_Rate_BPM  Sleep_Hours  \
# ...

# %%
x.columns
# Out:
# Index(['Log_ID', 'User_ID', 'Log_Date', 'Activity_Type', 'Duration_Minutes',
#        'Calories_Burned', 'Steps_Count', 'Avg_Heart_Rate_BPM', 'Sleep_Hours',
#        'Water_Intake_Liters', 'Mood_Rating'],
#       dtype='str')

# %%
x.shape
# Out:
# (3500, 11)

# %%
x.describe
# Out:
# <bound method NDFrame.describe of           Log_ID   User_ID    Log_Date Activity_Type  Duration_Minutes  \
# 0     LOG-502564  USR-2160  2024-01-01   Gym Workout               118
# 1     LOG-502968  USR-2237  2024-01-01       Cycling                32
# 2     LOG-503489  USR-2157  2024-01-01       Cycling                23
# 3     LOG-503464  USR-2040  2024-01-01          Yoga               107
# 4     LOG-503429  USR-2084  2024-01-01          HIIT                87
# ...          ...       ...         ...           ...               ...
# 3495  LOG-501088  USR-2179  2024-12-31   Gym Workout                43
# 3496  LOG-500706  USR-2200  2024-12-31   Gym Workout                94
# 3497  LOG-503184  USR-2102  2024-12-31      Swimming                28
# 3498  LOG-502469  USR-2231  2024-12-31          Yoga                41
# 3499  LOG-502716  USR-2143  2024-12-31      Swimming                42
#
#       Calories_Burned  Steps_Count  Avg_Heart_Rate_BPM  Sleep_Hours  \
# ...

# %%
x.head()
# Out:
#        Log_ID   User_ID    Log_Date Activity_Type  Duration_Minutes  \
# 0  LOG-502564  USR-2160  2024-01-01   Gym Workout               118
# 1  LOG-502968  USR-2237  2024-01-01       Cycling                32
# 2  LOG-503489  USR-2157  2024-01-01       Cycling                23
# 3  LOG-503464  USR-2040  2024-01-01          Yoga               107
# 4  LOG-503429  USR-2084  2024-01-01          HIIT                87
#
#    Calories_Burned  Steps_Count  Avg_Heart_Rate_BPM  Sleep_Hours  \
# 0              243         9219                 160          5.4
# 1              588        11088                 150          4.3
# 2              198         9557                 157          7.5
# 3              832         3044                 152          4.8
# 4              113        16114                 111          4.1
#
#    Water_Intake_Liters  Mood_Rating
# 0                  3.6            5
# 1                  1.2            4
# 2                  1.7            5
# ...

# %%
x.tail()
# Out:
#           Log_ID   User_ID    Log_Date Activity_Type  Duration_Minutes  \
# 3495  LOG-501088  USR-2179  2024-12-31   Gym Workout                43
# 3496  LOG-500706  USR-2200  2024-12-31   Gym Workout                94
# 3497  LOG-503184  USR-2102  2024-12-31      Swimming                28
# 3498  LOG-502469  USR-2231  2024-12-31          Yoga                41
# 3499  LOG-502716  USR-2143  2024-12-31      Swimming                42
#
#       Calories_Burned  Steps_Count  Avg_Heart_Rate_BPM  Sleep_Hours  \
# 3495              520        10574                 152          5.1
# 3496              704         3945                  74          5.6
# 3497              797         1118                 110          6.2
# 3498              860         6556                 100          4.6
# 3499               88         9231                 120          7.5
#
#       Water_Intake_Liters  Mood_Rating
# 3495                  2.2            3
# 3496                  1.7            4
# ...

# %%
x["Calories_Burned"].mean()
# Out:
# np.float64(478.9757142857143)
